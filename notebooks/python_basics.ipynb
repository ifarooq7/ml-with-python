# %% [markdown]
# <a href="https://colab.research.google.com/github/ifarooq7/ml-with-python/blob/main/notebooks/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Ijaz! Welcome to Google Colab")
# Out:
# Hello, Ijaz! Welcome to Google Colab
